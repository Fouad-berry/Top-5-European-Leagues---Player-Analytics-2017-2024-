# %% [markdown]
# # 🧱 03 — Construction des datamarts

# %%
import sys
sys.path.append('..')

from src.data_loader import load_processed, save_datamart, save_export
from src.datamarts import build_all

df = load_processed()
dms = build_all(df)
print('Datamarts :', list(dms.keys()))

# %% [markdown]
# ## KPIs globaux

# %%
dms['global_kpis'].T

# %% [markdown]
# ## Ligue × Saison

# %%
dms['league_season']

# %% [markdown]
# ## Top 10 buteurs par saison

# %%
dms['top_scorers_by_season'].head(20)

# %% [markdown]
# ## Performance par équipe (top 15 buts toutes saisons)

# %%
dms['team_performance'].sort_values('total_goals', ascending=False).head(15)

# %% [markdown]
# ## Profil par position

# %%
dms['position_profile']

# %% [markdown]
# ## Top sur-performeurs xG

# %%
dms['xg_finishing'].head(20)

# %% [markdown]
# ## Top nations

# %%
dms['top_nations']

# %% [markdown]
# ## Sauvegarde

# %%
for name, dm in dms.items():
    path = save_datamart(dm, name)
    print(f'✓ {path.name}')
